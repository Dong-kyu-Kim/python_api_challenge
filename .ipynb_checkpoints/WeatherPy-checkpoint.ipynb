# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# !pip install citypy
# Out:
# ERROR: Could not find a version that satisfies the requirement citypy (from versions: none)
# ERROR: No matching distribution found for citypy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %%
cities
# Out:
# ['flying fish cove',
#  'zemio',
#  'letlhakane',
#  'longyearbyen',
#  'bilibino',
#  'tura',
#  'tayoltita',
#  'weno',
#  'itaituba',
#  'vilyuchinsk',
#  'ola',
#  'waitangi',
#  'kavaratti',
#  'el soberbio',
#  'el quebrachal',
#  'chu',
#  'grytviken',
#  'west island',
#  'mombetsu',
#  'suncho corral',
#  'shache',
#  'howard springs',
#  'east london',
#  'siwa oasis',
#  'ust-tsilma',
#  'amahai',
#  'rio grande',
#  'port alfred',
#  'edinburgh of the seven seas',
#  'arraial do cabo',
#  'adamstown',
#  'guerrero negro',
#  'talnakh',
#  'kara suu',
#  'sitka',
#  'kingston',
#  'wailua homesteads',
#  'port-aux-francais',
#  'kota belud',
#  'uturoa',
#  'blackmans bay',
#  'olhao',
#  "nar'yan-mar",
#  'puerto natales',
#  'port augusta',
#  'waveland',
#  'whakatane',
#  'albany',
#  'konarka',
#  "ts'khinvali",
#  'vorgashor',
#  'raub',
#  'revda',
#  'ebon',
#  'mpanda',
#  'port elizabeth',
#  'sao joao da barra',
#  'margaret river',
#  'darlowo',
#  'aasiaat',
#  'tamanrasset',
#  'orkney',
#  'bethel',
#  'nicoya',
#  'olonkinbyen',
#  'gudauta',
#  'minot',
#  'khorugh',
#  'petropavlovsk-kamchatsky',
#  'ellsworth',
#  'ribeira grande',
#  'xilin hot',
#  'puerto san jose',
#  'saldanha',
#  'valdez',
#  'rapid city',
#  'kavieng',
#  'hadibu',
#  'yellowknife',
#  'ilulissat',
#  'port lincoln',
#  'erenhot',
#  'invercargill',
#  'nova vicosa',
#  'lerwick',
#  'yuzhno-kurilsk',
#  'shantobe',
#  'ancud',
#  'hiriyur',
#  'hotan',
#  'terenos',
#  'naze',
#  'nova sintra',
#  'marquette',
#  'akureyri',
#  'kismayo',
#  "hayma'",
#  'amasra',
#  'assab',
#  'conception bay south',
#  'hermoso campo',
#  'ta`u',
#  'puerto ayora',
#  'bredasdorp',
#  'belmonte',
#  'codrington',
#  'taiohae',
#  'qaqortoq',
#  'iqaluit',
#  'puerto baquerizo moreno',
#  'port mathurin',
#  'gevrai',
#  'birzebbuga',
#  'tingi',
#  'rovaniemi',
#  'jamestown',
#  'stanley',
#  'sao jose da coroa grande',
#  'tucurui',
#  'korla',
#  'neka',
#  'udachny',
#  'kulhudhuffushi',
#  'atafu village',
#  "kapa'a",
#  'isafjordur',
#  'avarua',
#  'meadow lakes',
#  'alofi',
#  'jamaame',
#  'lumut',
#  'galesong',
#  'nyurba',
#  'remire-montjoly',
#  "n'zeto",
#  'tromso',
#  'antsiranana',
#  'papatowai',
#  'college',
#  'rosarito',
#  'laguna',
#  'guarapari',
#  'urangan',
#  'maba',
#  'mwene-ditu',
#  'dudinka',
#  'lihue',
#  'elko',
#  'shiqian',
#  'sinabang',
#  'greci',
#  'pajok',
#  "ha'il",
#  'altay',
#  'thompson',
#  'thunder bay',
#  'rongelap',
#  'vila velha',
#  'neiafu',
#  'kodiak',
#  'petauke',
#  'utrik',
#  'molde',
#  'hamilton',
#  'arauco',
#  'tiksi',
#  'tranovaho',
#  'korsakov',
#  'bubaque',
#  'hawaiian paradise park',
#  'arraias',
#  'fale old settlement',
#  'ashta',
#  'malango',
#  'khovd',
#  'alaca',
#  'granada',
#  'georgetown',
#  'aykhal',
#  'whitehorse',
#  'karaton',
#  'holly springs',
#  'kidal',
#  'badger',
#  'juan de ayolas',
#  'midvagur',
#  'ketchikan',
#  'devinuwara',
#  'bartica',
#  'acarau',
#  'cabo san lucas',
#  'enewetak',
#  'sattahip',
#  'okulovka',
#  'dazhou',
#  'arboletes',
#  "port saint john's",
#  'punta arenas',
#  'palmer',
#  'puerto san carlos',
#  'verkhniye kigi',
#  'san antonio de pale',
#  'miramar beach',
#  'fortuna',
#  'yabelo',
#  'la ronge',
#  'fenoarivo atsinanana',
#  "muzayri'",
#  'aur',
#  'merizo village',
#  'kulachi',
#  'gizo',
#  'zhaotong',
#  'anadyr',
#  'kyzylorda',
#  'el colomo',
#  'vorkuta',
#  'taltal',
#  'haiku-pauwela',
#  'toga village',
#  'chamical',
#  'kuta',
#  'suai',
#  'carboneras',
#  'harper',
#  'hammerfest',
#  'tralee',
#  'acapulco de juarez',
#  'xining',
#  'bardai',
#  'marsh harbour',
#  'touros',
#  'newman',
#  'portland',
#  'papao',
#  'paraiso',
#  'kulia village',
#  'turpan',
#  'al hazm',
#  'guapi',
#  'margate',
#  'murzuq',
#  'selfoss',
#  'bambari',
#  'mount pleasant',
#  'anonang',
#  'gadzhiyevo',
#  'hermanus',
#  'nemuro',
#  'khash',
#  'nikolayevsk-on-amure',
#  'ushuaia',
#  'mar del plata',
#  'daru',
#  'khandyga',
#  'robertsport',
#  'coquimbo',
#  'kruisfontein',
#  'praia',
#  'iskateley',
#  'tual',
#  'tazovsky',
#  'woods creek',
#  'magong',
#  'igarka',
#  'mahina',
#  'cidreira',
#  'pont rouge',
#  'lompoc',
#  'novo aripuana',
#  'keflavik',
#  'chui',
#  'novaya ladoga',
#  'fort bragg',
#  'little cayman',
#  'ranau',
#  'peace river',
#  'eurajoki',
#  'medicine hat',
#  'port blair',
#  'anabar',
#  'callao',
#  'guercif',
#  'carnarvon',
#  'putten',
#  'gaspe',
#  'santa terezinha',
#  'ginir',
#  'serenje',
#  "st. john's",
#  'tabas',
#  'kasongo',
#  'qamdo',
#  'geltendorf',
#  'aurora',
#  'rouissat',
#  "arkhangel'sk",
#  'msowero',
#  'broome',
#  'mulayjah',
#  'tangalle',
#  'santa marta',
#  'ambodifotatra',
#  'micheweni',
#  'maues',
#  'sofifi',
#  'pacific grove',
#  'happy valley-goose bay',
#  'new norfolk',
#  'kapuskasing',
#  'klyuchi',
#  'turaif',
#  'biloela',
#  'kitimat',
#  'mangai',
#  'rikaze',
#  'beni',
#  'kenora',
#  'ilebo',
#  'sogamoso',
#  'semera',
#  'targu carbunesti',
#  'mount gambier',
#  'jinghong',
#  'lebu',
#  'egilsstadir',
#  'queenstown',
#  'altai',
#  'shalqar',
#  'cockburn town',
#  'meulaboh',
#  'sur',
#  'dunedin',
#  'lundazi',
#  'saipan',
#  'kinablangan',
#  'vadso',
#  'mana',
#  'saint-joseph',
#  'upington',
#  'nishinoomote',
#  'porto seguro',
#  'chibougamau',
#  'alice springs',
#  'lamu',
#  'bereznik',
#  'kattivakkam',
#  'bryne',
#  'zaysan',
#  'bandon',
#  'kununurra',
#  'ottawa',
#  'serro',
#  'ponta delgada',
#  'baiti',
#  'privolzhskiy',
#  'lai',
#  'hithadhoo',
#  'minas de marcona',
#  'kirkland lake',
#  'upper hutt',
#  'colonia',
#  'taoudenni',
#  'kloulklubed',
#  'yelabuga',
#  'rehoboth',
#  'ust-nera',
#  'akobo',
#  'malvan',
#  'machico',
#  'bamboo flat',
#  'vila franca do campo',
#  'xiva',
#  'kuqa',
#  'mithi',
#  'tubarjal',
#  'sines',
#  'arochukwu',
#  'mejit',
#  'terrace',
#  'dinguiraye',
#  "bich'vinta",
#  'yakeshi',
#  'prado',
#  'brisas de zicatela',
#  'morehead city',
#  'yamada',
#  'monticello',
#  'la sarre',
#  'sidi merouane',
#  'saint-philippe',
#  'san antonio del estrecho',
#  'guatrache',
#  'penzance',
#  'jijiga',
#  'geraldton',
#  'crane',
#  'basco',
#  'gazli',
#  'vanino',
#  'shixing',
#  'alaghsas',
#  'chonchi',
#  'as sulayyil',
#  'belomorsk',
#  'terenozek',
#  'shendi',
#  "la'ie",
#  'balqash',
#  'trinidad',
#  'pariaman',
#  'karratha',
#  'conceicao do araguaia',
#  'jinchang',
#  'kill devil hills',
#  'hami',
#  'axim',
#  'coihueco',
#  'horsham',
#  'al ghayzah',
#  'sisimiut',
#  'tobelo',
#  'constantia',
#  'arteixo',
#  'nuuk',
#  'san jeronimo amanalco',
#  'williams lake',
#  'el daein',
#  'gazipasa',
#  'ascencion de guarayos',
#  'plettenberg bay',
#  'onega',
#  'saacow',
#  "'ohonua",
#  'three points',
#  'sokoni',
#  'chapaev',
#  'raduzhny',
#  'svobodnyy',
#  'solnechnyy',
#  'alta',
#  'neijiang',
#  "bu'aale",
#  'pisco',
#  'pustoshka',
#  'hasaki',
#  'columbus',
#  'navlya',
#  'lhasa',
#  'kone',
#  'howrah',
#  'salinas',
#  'inhambane',
#  'sarina',
#  'ciudad lazaro cardenas',
#  'ulladulla',
#  'bundibugyo',
#  'shimoda',
#  'auki',
#  'chiili',
#  'broken hill',
#  'yol',
#  'suihua',
#  'jaciara',
#  'monte cristo',
#  'jaen',
#  'las khorey',
#  'kostomuksha',
#  'razole',
#  'pervomayskoye',
#  'plastun',
#  'jilib',
#  'veraval',
#  'walvis bay',
#  'labrador city',
#  'nuriootpa',
#  'itaiba',
#  'sechura',
#  'prince rupert',
#  'chabua',
#  'painesville',
#  'cartagena',
#  'uzgen',
#  'pedro ii',
#  'cuyo',
#  'ca mau',
#  'goksun',
#  'gebeit',
#  'afaahiti',
#  'bayganin',
#  'chifeng',
#  'xiongzhou',
#  'gornyy',
#  'chipinge',
#  'al qadarif',
#  'leticia',
#  'ilek',
#  'holualoa',
#  'andergrove',
#  'rabaul',
#  'richards bay',
#  'port isabel',
#  'rabo de peixe',
#  'arteche',
#  'sao joaquim',
#  'porbandar',
#  'pangai',
#  'tazacorte',
#  'ahau',
#  'luderitz',
#  'hatillo',
#  'grand falls-windsor',
#  'ponmana',
#  'kuraymah',
#  'figuig (centre)',
#  'da nang',
#  'mitu',
#  'anjiang',
#  'debre sina',
#  'cabedelo',
#  'dedza',
#  'moissala',
#  'an nuhud',
#  'bejubang dua',
#  'argo',
#  'vingt cinq',
#  'boguchany',
#  'ishim',
#  'kolonia town',
#  'bantay',
#  'miri',
#  'kuybyshev',
#  'wloszczowa',
#  'masuguru',
#  'trujillo',
#  'arrifes',
#  'tavda',
#  'laiyang',
#  'hornsby bend',
#  'north shore',
#  'laojunmiao',
#  "nuku'alofa",
#  'balsas',
#  'chinon',
#  'kaoma',
#  'sinah',
#  'kendari',
#  'takeo',
#  'zhigalovo',
#  'lorengau',
#  'bikenibeu village',
#  'maumere',
#  'fort st. john',
#  'hengchun',
#  'verkhnevilyuysk',
#  'ouarzazat',
#  'fort mcmurray',
#  'sola',
#  'justo daract',
#  'caranan',
#  'sona',
#  'kristiansund',
#  'rouyn-noranda',
#  'huntington',
#  'fuvahmulah',
#  'kuching',
#  'galle',
#  'garoowe',
#  'yanam',
#  'amga',
#  'labytnangi',
#  'homer',
#  'changyon',
#  'sandnessjoen',
#  'baruun-urt',
#  'smithers',
#  'vinukonda',
#  'sereflikochisar',
#  'okha',
#  'phalaborwa',
#  'imbituba',
#  'roma',
#  'salahonda',
#  'manuel ojinaga',
#  'arevalo',
#  'la passe',
#  'saku',
#  'burkburnett',
#  'dickinson',
#  'den burg',
#  'guateque',
#  "kinel'-cherkassy",
#  'cargados carajos',
#  'saint-francois',
#  'le port',
#  'madaoua',
#  'kurchum',
#  'arvayheer',
#  'samarinda',
#  'vilyuysk',
#  'starobin',
#  'bulawayo',
#  'petrolina',
#  'palu',
#  'lloydminster',
#  'aginskoye',
#  'woolgoolga',
#  'laghouat',
#  'perm',
#  'buala',
#  'calvinia',
#  'san patricio',
#  'champerico']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"
print(url + "&q=san francisco")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&appid=b79cc516f0cd5f00393e83c5425f9bef&q=san francisco

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=metric&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}&q={city}"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | flying fish cove
# Processing Record 2 of Set 1 | zemio
# Processing Record 3 of Set 1 | letlhakane
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | bilibino
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | tayoltita
# Processing Record 8 of Set 1 | weno
# Processing Record 9 of Set 1 | itaituba
# Processing Record 10 of Set 1 | vilyuchinsk
# Processing Record 11 of Set 1 | ola
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 
# Processing Record 15 of Set 4 | tiksi
# Processing Record 16 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 17 of Set 4 | korsakov
# Processing Record 18 of Set 4 | bubaque
# Processing Record 19 of Set 4 | hawaiian paradise park
# Processing Record 20 of Set 4 | arraias
# Processing Record 21 of Set 4 | fale old settlement
# Processing Record 22 of Set 4 | ashta
# Processing Record 23 of Set 4 | malango
# Processing Record 24 of Set 4 | khovd
# Processing Record 25 of Set 4 | alaca
# Processing Record 26 of Set 4 | granada
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | aykhal
# Processing Record 29 of Set 4 | whitehorse
# Processing Record 30 of Set 4 | karaton
# Processing Record 31 of Set 4 | holly springs
# Processing Record 32 of Set 4 | kidal
# Processing Record 33 of Set 4 | badger
# Processing Record 34 of Set 4 | juan de ayolas
# Processing Record 35 of Set 4 | midvagur
# Processing Record 36 of Set 4 | ketchikan
# Processing Record 37 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 38 of Set 4 | bartica
# Processing Record 39 of Set 4 | acarau
# Processing Record 40 of Set 4 | cabo san lucas
# Processing Record 41 of Set 4 | enewetak
# Processing Record 42 of Set 4 | sattahip
# Processing Record 43 of Set 4 | okulovka
# Processing Record 44 of Set 4 | dazhou
# Processing Record 45 of Set 4 | arboletes
# Processing Record 46 of Set 4 | port saint john's
# Processing Record 47 of Set 4 | punta arenas
# Processing Record 48 of Set 4 | palmer
# Processing Record 49 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 0 of Set 5 | verkhniye kigi
# Processing Record 1 of Set 5 | san antonio de pale
# Processing Record 2 of Set 5 | miramar beach
# Processing Record 3 of Set 5 | fortuna
# Processing Record 4 of Set 5 | yabelo
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | fenoarivo atsinanana
# Processing Record 7 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 8 of Set 5 | aur
# Processing Record 9 of Set 5 | merizo village
# Processing Record 10 of Set 5 | kulachi
# Processing Record 11 of Set 5 | gizo
# Processing Record 12 of Set 5 | zhaotong
# Processing Record 13 of Set 5 | anadyr
# Processing Record 14 of Set 5 | kyzylorda
# Processing Record 15 of Set 5 | el colomo
# Processing Record 16 of Set 5 | vorkuta
# Processing Record 17 of Set 5 | taltal
# Processing Record 18 of Set 5 | haiku-pauwela
# Processing Record 19 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 20 of Set 5 | chamical
# Processing Record 21 of Set 5 | kuta
# Processing Record 22 of Set 5 | suai
# City not found. Skipping...
# Processing Record 23 of Set 5 | carboneras
# Processing Record 24 of Set 5 | harper
# Processing Record 25 of Set 5 | hammerfest
# Processing Record 26 of Set 5 | tralee
# Processing Record 27 of Set 5 | acapulco de juarez
# Processing Record 28 of Set 5 | xining
# Processing Record 29 of Set 5 | bardai
# Processing Record 30 of Set 5 | marsh harbour
# Processing Record 31 of Set 5 | touros
# Processing Record 32 of Set 5 | newman
# Processing Record 33 of Set 5 | portland
# Processing Record 34 of Set 5 | papao
# Processing Record 35 of Set 5 | paraiso
# Processing Record 36 of Set 5 | kulia village
# City not found. Skipping...
# Processing Record 37 of Set 5 | turpan
# Processing Record 38 of Set 5 | al hazm
# Processing Record 39 of Set 5 | guapi
# Processing Record 40 of Set 5 | margate
# Processing Record 41 of Set 5 | murzuq
# Processing Record 42 of Set 5 | selfoss
# Processing Record 43 of Set 5 | bambari
# Processing Record 44 of Set 5 | mount pleasant
# Processing Record 45 of Set 5 | anonang
# Processing Record 46 of Set 5 | gadzhiyevo
# Processing Record 47 of Set 5 | hermanus
# Processing Record 48 of Set 5 | nemuro
# Processing Record 49 of Set 5 | khash
# Processing Record 0 of Set 6 | nikolayevsk-on-amure
# Processing Record 1 of Set 6 | ushuaia
# Processing Record 2 of Set 6 | mar del plata
# Processing Record 3 of Set 6 | daru
# Processing Record 4 of Set 6 | khandyga
# Processing Record 5 of Set 6 | robertsport
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | kruisfontein
# Processing Record 8 of Set 6 | praia
# Processing Record 9 of Set 6 | iskateley
# Processing Record 10 of Set 6 | tual
# Processing Record 11 of Set 6 | tazovsky
# Processing Record 12 of Set 6 | woods creek
# Processing Record 13 of Set 6 | magong
# Processing Record 14 of Set 6 | igarka
# Processing Record 15 of Set 6 | mahina
# Processing Record 16 of Set 6 | cidreira
# Processing Record 17 of Set 6 | pont rouge
# Processing Record 18 of Set 6 | lompoc
# Processing Record 19 of Set 6 | novo aripuana
# Processing Record 20 of Set 6 | keflavik
# Processing Record 21 of Set 6 | chui
# Processing Record 22 of Set 6 | novaya ladoga
# Processing Record 23 of Set 6 | fort bragg
# Processing Record 24 of Set 6 | little cayman
# City not found. Skipping...
# Processing Record 25 of Set 6 | ranau
# Processing Record 26 of Set 6 | peace river
# Processing Record 27 of Set 6 | eurajoki
# Processing Record 28 of Set 6 | medicine hat
# Processing Record 29 of Set 6 | port blair
# Processing Record 30 of Set 6 | anabar
# City not found. Skipping...
# Processing Record 31 of Set 6 | callao
# Processing Record 32 of Set 6 | guercif
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | putten
# Processing Record 35 of Set 6 | gaspe
# Processing Record 36 of Set 6 | santa terezinha
# Processing Record 37 of Set 6 | ginir
# Processing Record 38 of Set 6 | serenje
# Processing Record 39 of Set 6 | st. john's
# Processing Record 40 of Set 6 | tabas
# Processing Record 41 of Set 6 | kasongo
# Processing Record 42 of Set 6 | qamdo
# Processing Record 43 of Set 6 | geltendorf
# Processing Record 44 of Set 6 | aurora
# Processing Record 45 of Set 6 | rouissat
# Processing Record 46 of Set 6 | arkhangel'sk
# Processing Record 47 of Set 6 | msowero
# Processing Record 48 of Set 6 | broome
# Processing Record 49 of Set 6 | mulayjah
# Processing Record 0 of Set 7 | tangalle
# Processing Record 1 of Set 7 | santa marta
# Processing Record 2 of Set 7 | ambodifotatra
# Processing Record 3 of Set 7 | micheweni
# Processing Record 4 of Set 7 | maues
# Processing Record 5 of Set 7 | sofifi
# Processing Record 6 of Set 7 | pacific grove
# Processing Record 7 of Set 7 | happy valley-goose bay
# Processing Record 8 of Set 7 | new norfolk
# Processing Record 9 of Set 7 | kapuskasing
# Processing Record 10 of Set 7 | klyuchi
# Processing Record 11 of Set 7 | turaif
# Processing Record 12 of Set 7 | biloela
# Processing Record 13 of Set 7 | kitimat
# Processing Record 14 of Set 7 | mangai
# Processing Record 15 of Set 7 | rikaze
# Processing Record 16 of Set 7 | beni
# Processing Record 7 of Set 10 | shimoda
# Processing Record 8 of Set 10 | auki
# Processing Record 9 of Set 10 | chiili
# City not found. Skipping...
# Processing Record 10 of Set 10 | broken hill
# Processing Record 11 of Set 10 | yol
# Processing Record 12 of Set 10 | suihua
# Processing Record 13 of Set 10 | jaciara
# Processing Record 14 of Set 10 | monte cristo
# Processing Record 15 of Set 10 | jaen
# Processing Record 16 of Set 10 | las khorey
# Processing Record 17 of Set 10 | kostomuksha
# Processing Record 18 of Set 10 | razole
# Processing Record 19 of Set 10 | pervomayskoye
# Processing Record 20 of Set 10 | plastun
# Processing Record 21 of Set 10 | jilib
# Processing Record 22 of Set 10 | veraval
# Processing Record 23 of Set 10 | walvis bay
# Processing Record 24 of Set 10 | labrador city
# Processing Record 25 of Set 10 | nuriootpa
# Processing Record 26 of Set 10 | itaiba
# Processing Record 27 of Set 10 | sechura
# Processing Record 28 of Set 10 | prince rupert
# Processing Record 29 of Set 10 | chabua
# Processing Record 30 of Set 10 | painesville
# Processing Record 31 of Set 10 | cartagena
# Processing Record 32 of Set 10 | uzgen
# Processing Record 33 of Set 10 | pedro ii
# Processing Record 34 of Set 10 | cuyo
# Processing Record 35 of Set 10 | ca mau
# Processing Record 36 of Set 10 | goksun
# Processing Record 37 of Set 10 | gebeit
# Processing Record 38 of Set 10 | afaahiti
# Processing Record 39 of Set 10 | bayganin
# Processing Record 40 of Set 10 | chifeng
# Processing Record 41 of Set 10 | xiongzhou
# Processing Record 42 of Set 10 | gornyy
# Processing Record 43 of Set 10 | chipinge
# Processing Record 44 of Set 10 | al qadarif
# Processing Record 45 of Set 10 | leticia
# Processing Record 46 of Set 10 | ilek
# Processing Record 47 of Set 10 | holualoa
# Processing Record 48 of Set 10 | andergrove
# Processing Record 49 of Set 10 | rabaul
# Processing Record 0 of Set 11 | richards bay
# Processing Record 1 of Set 11 | port isabel
# Processing Record 2 of Set 11 | rabo de peixe
# Processing Record 3 of Set 11 | arteche
# Processing Record 4 of Set 11 | sao joaquim
# Processing Record 5 of Set 11 | porbandar
# Processing Record 6 of Set 11 | pangai
# Processing Record 7 of Set 11 | tazacorte
# Processing Record 8 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 9 of Set 11 | luderitz
# Processing Record 10 of Set 11 | hatillo
# Processing Record 11 of Set 11 | grand falls-windsor
# Processing Record 12 of Set 11 | ponmana
# City not found. Skipping...
# Processing Record 13 of Set 11 | kuraymah
# Processing Record 14 of Set 11 | figuig (centre)
# Processing Record 15 of Set 11 | da nang
# Processing Record 16 of Set 11 | mitu
# Processing Record 17 of Set 11 | anjiang
# Processing Record 18 of Set 11 | debre sina
# Processing Record 19 of Set 11 | cabedelo
# Processing Record 20 of Set 11 | dedza
# Processing Record 21 of Set 11 | moissala
# Processing Record 22 of Set 11 | an nuhud
# Processing Record 23 of Set 11 | bejubang dua
# City not found. Skipping...
# Processing Record 24 of Set 11 | argo
# Processing Record 25 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 26 of Set 11 | boguchany
# Processing Record 27 of Set 11 | ishim
# Processing Record 28 of Set 11 | kolonia town
# Processing Record 29 of Set 11 | bantay
# Processing Record 30 of Set 11 | miri
# Processing Record 31 of Set 11 | kuybyshev
# Processing Record 32 of Set 11 | wloszczowa
# Processing Record 33 of Set 11 | masuguru
# Processing Record 34 of Set 11 | trujillo
# Processing Record 35 of Set 11 | arrifes
# Processing Record 36 of Set 11 | tavda
# Processing Record 37 of Set 11 | laiyang
# Processing Record 38 of Set 11 | hornsby bend
# Processing Record 39 of Set 11 | north shore
# Processing Record 40 of Set 11 | laojunmiao
# Processing Record 41 of Set 11 | nuku'alofa
# Processing Record 42 of Set 11 | balsas
# Processing Record 43 of Set 11 | chinon
# Processing Record 44 of Set 11 | kaoma
# Processing Record 45 of Set 11 | sinah
# Processing Record 46 of Set 11 | kendari
# Processing Record 47 of Set 11 | takeo
# Processing Record 48 of Set 11 | zhigalovo
# Processing Record 49 of Set 11 | lorengau
# Processing Record 0 of Set 12 | bikenibeu village
# Processing Record 1 of Set 12 | maumere
# Processing Record 2 of Set 12 | fort st. john
# Processing Record 3 of Set 12 | hengchun
# Processing Record 4 of Set 12 | verkhnevilyuysk
# Processing Record 5 of Set 12 | ouarzazat
# Processing Record 6 of Set 12 | fort mcmurray
# Processing Record 7 of Set 12 | sola
# Processing Record 8 of Set 12 | justo daract
# Processing Record 9 of Set 12 | caranan
# Processing Record 10 of Set 12 | sona
# Processing Record 11 of Set 12 | kristiansund
# Processing Record 12 of Set 12 | rouyn-noranda
# Processing Record 13 of Set 12 | huntington
# Processing Record 14 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 15 of Set 12 | kuching
# Processing Record 16 of Set 12 | galle
# Processing Record 17 of Set 12 | garoowe
# Processing Record 18 of Set 12 | yanam
# Processing Record 19 of Set 12 | amga
# Processing Record 20 of Set 12 | labytnangi
# Processing Record 21 of Set 12 | homer
# Processing Record 22 of Set 12 | changyon
# Processing Record 23 of Set 12 | sandnessjoen
# Processing Record 24 of Set 12 | baruun-urt
# Processing Record 25 of Set 12 | smithers
# Processing Record 26 of Set 12 | vinukonda
# Processing Record 27 of Set 12 | sereflikochisar
# Processing Record 28 of Set 12 | okha
# Processing Record 29 of Set 12 | phalaborwa
# Processing Record 30 of Set 12 | imbituba
# Processing Record 31 of Set 12 | roma
# Processing Record 32 of Set 12 | salahonda
# Processing Record 33 of Set 12 | manuel ojinaga
# City not found. Skipping...
# Processing Record 34 of Set 12 | arevalo
# Processing Record 35 of Set 12 | la passe
# Processing Record 36 of Set 12 | saku
# Processing Record 37 of Set 12 | burkburnett
# Processing Record 38 of Set 12 | dickinson
# Processing Record 39 of Set 12 | den burg
# Processing Record 40 of Set 12 | guateque
# Processing Record 41 of Set 12 | kinel'-cherkassy
# Processing Record 42 of Set 12 | cargados carajos
# City not found. Skipping...
# Processing Record 43 of Set 12 | saint-francois
# Processing Record 44 of Set 12 | le port
# Processing Record 45 of Set 12 | madaoua
# Processing Record 46 of Set 12 | kurchum
# Processing Record 47 of Set 12 | arvayheer
# Processing Record 48 of Set 12 | samarinda
# Processing Record 49 of Set 12 | vilyuysk
# Processing Record 0 of Set 13 | starobin
# Processing Record 1 of Set 13 | bulawayo
# Processing Record 2 of Set 13 | petrolina
# Processing Record 3 of Set 13 | palu
# Processing Record 4 of Set 13 | lloydminster
# Processing Record 5 of Set 13 | aginskoye
# Processing Record 6 of Set 13 | woolgoolga
# Processing Record 7 of Set 13 | laghouat
# Processing Record 8 of Set 13 | perm
# Processing Record 9 of Set 13 | buala
# Processing Record 10 of Set 13 | calvinia
# Processing Record 11 of Set 13 | san patricio
# Processing Record 12 of Set 13 | champerico
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  flying fish cove -10.4217  105.6791     27.82        69          75
# 1             zemio   5.0314   25.1361     21.19        96          98
# 2        letlhakane -21.4167   25.5833      8.04        33           0
# 3      longyearbyen  78.2186   15.6401      8.91        93         100
# 4          bilibino  68.0546  166.4372     10.66        75          97
#
#    Wind Speed Country        Date
# 0        6.17      CX  1722228974
# 1        0.59      CF  1722228976
# 2        4.65      BW  1722228977
# 3        4.63      SJ  1722228978
# 4        2.22      RU  1722228646

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        flying fish cove -10.4217  105.6791     27.82        69          75
# 1                   zemio   5.0314   25.1361     21.19        96          98
# 2              letlhakane -21.4167   25.5833      8.04        33           0
# 3            longyearbyen  78.2186   15.6401      8.91        93         100
# 4                bilibino  68.0546  166.4372     10.66        75          97
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      CX  1722228974
# 1              0.59      CF  1722228976
# 2              4.65      BW  1722228977
# 3              4.63      SJ  1722228978
# 4              2.22      RU  1722228646

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor = 'red',
    linewidths = 1,
    marker = 'o',
    alpha = 0.8,
    label = "Cities"
)

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Temperature (%s) ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Tem (C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor = 'green',
    linewidths = 1,
    marker = 'o',
    alpha = 0.8,
    label = "Cities"
)
# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Humidity (%s) ({date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor = 'orange',
    linewidths = 1,
    marker = 'o',
    alpha = 0.8,
    label = "Cities"
)

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Cloudiness (%s) ({date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(
    city_data_df["Lat"],
    city_data_df["Wind Speed"],
    edgecolor = 'purple',
    linewidths = 1,
    marker = 'o',
    alpha = 0.8,
    label = "Cities"
)

# Incorporate the other graph properties
date = time.strftime("%Y-%m-%d")
plt.title(f"City Max Latitude vs. Wind Speed (%s) ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_value, y_value, title, text_coord):

    # Compute linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_value = x_value * slope + intercept
    line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"

    plt.scatter(x_value, y_value)
    plt.plot(x_value, regress_value, "r-")
    plt.annotate(line_eq, text_coord, fontsize = 15, color = 'red')
    plt.xlabel("Lat")
    plt.ylabel(title)
    print(f"The r-value is {rvalue ** 2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               zemio   5.0314   25.1361     21.19        96          98
# 3        longyearbyen  78.2186   15.6401      8.91        93         100
# 4            bilibino  68.0546  166.4372     10.66        75          97
# 5                tura  25.5198   90.2201     30.99        70         100
# 6           tayoltita  24.0833 -105.9333     23.30        91          53
#
#          Wind Speed Country        Date
# City_ID
# 1              0.59      CF  1722228976
# 3              4.63      SJ  1722228978
# 4              2.22      RU  1722228646
# 5              2.45      IN  1722228980
# 6              2.04      MX  1722228981

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        flying fish cove -10.4217  105.6791     27.82        69          75
# 2              letlhakane -21.4167   25.5833      8.04        33           0
# 8                itaituba  -4.2761  -55.9836     25.48        53          88
# 11               waitangi -43.9535 -176.5597     11.57        94          99
# 13            el soberbio -27.2985  -54.1988     17.95       100          99
#
#          Wind Speed Country        Date
# City_ID
# 0              6.17      CX  1722228974
# 2              4.65      BW  1722228977
# 8              0.92      BR  1722228613
# 11             1.34      NZ  1722228576
# 13             0.51      AR  1722228808

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (48, 35))
# Out:
# The r-value is 0.31628088588203657

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (-55, 25))
# Out:
# The r-value is 0.6191358083372114

# %% [markdown]
# **Discussion about the linear relationship:**
# 1. Linear regression on Northern Hemisphere (y = -0.2x + 30.39):
#
# This linear regression equation indicates that the correlation between maximum temperature and the Northern Hemisphere latitude has a (-) relationship. The maximum temperature tends to decrease with increasing latitude. The slope of the equation indicates that for every 1 degree increase in latitude, the maximum temperature decreases by 0.2 degrees.
#
# 2. Linear regression on Southern Hemisphere (y = 0.49x + 27.65):
#
# This shaping regression equation shows the correlation between the highest temperature and latitude, based on the southern hemisphere. As you can see from the slope, for every 1 degree increase in latitude, the highest temperature increases by 0.49 degrees. It shows a (+) correlation, and the highest temperature increases as the stomach increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (45, 10))
# Out:
# The r-value is 0.005315155708145901

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-55, 20))
# Out:
# The r-value is 0.004114139286574492

# %% [markdown]
# **Discussion about the linear relationship:**
# 1. Northern Hemisphere (y = −0.08x + 72.68):
#
# This linear regression equation has a negative (-) correlation that decreases the maximum humidity as the latitude increases. The value of the slope is -0.08, and the humidity at which the latitude increases by 1 degree decreases by 0.08% on average.
#
# 2. Southern Hemisphere (y = -0.11x + 64.45):
#
# According to this linear regression equation, humidity appears to have a negative (-) correlation with increasing latitude in the southern hemisphere. We find that increasing latitude by 1 degree due to the slope of the equation decreases humidity by 0.11% on average.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-3, 2))
# Out:
# The r-value is 0.003409536347268896

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-55, 25))
# Out:
# The r-value is 0.03587745357413229

# %% [markdown]
# **Discussion about the linear relationship:**
# 1. Northern Hemisphere (y = -0.11x + 63.67):
#
# The slope of this linear regression equation is -0.11, which shows that an increase of 1 degree in latitude decreases the amount of clouds by 0.11%. This shows a negative (-) correlation in which clouds shrink as latitude increases.
#
# 2. Southern Hemisphere (y = -0.55x + 30.46):
#
# This linear regression equation shows that cloud cover tends to decrease as latitude increases in the Southern Hemisphere (i.e., toward Antarctica). For example, for every 1 degree increase in latitude, cloud cover decreases by about 0.55%. We can see that it has a (-) correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (10, 15))
# Out:
# The r-value is 0.0017081234262153674

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-30, 12))
# Out:
# The r-value is 0.022458054554310665

# %% [markdown]
# **Discussion about the linear relationship:**
# 1. Northern Hemisphere (y = 0.01x + 3.4):
#
# This linear regression equation has a positive (+) correlation that we can see that the latitude increases with increasing Wind Speed. We can see that a 1 degree increase in latitude increases the wind speed by 0.01. This positive trend can be considered insignificant.
#
# 2. Southern Hemisphere (y = -0.03x + 3.21):
#
# This shaping regression equation shows that an increase of 1 degree in latitude decreases the wind speed by 0.03. It shows a (-) correlation, but we find that the relationship is minimal. Overall, the wind speed decreases slightly as the latitude increases.
